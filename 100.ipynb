# %%
from keras.models import Model
from keras.layers import Dense, Flatten, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing import image
from sklearn.metrics import confusion_matrix, mean_squared_error

# %%
height = 300
width = 300

# %%
# Define directories for training and validation data.
train_dir = "C:/Users/ASUS/Downloads/Identification_of_Fake_Currency_Found_in_India-main/Identification_of_Fake_Currency_Found_in_India-main/Dataset(100)/Training"
validation_dir = "C:/Users/ASUS/Downloads/Identification_of_Fake_Currency_Found_in_India-main/Identification_of_Fake_Currency_Found_in_India-main/Dataset(100)/Validation"

# %%
batch_size = 8

# %%
# Data augmentation for training images.
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input, rotation_range=90,
                                   horizontal_flip=True, vertical_flip=True)
train_generator = train_datagen.flow_from_directory(train_dir, target_size=(height, width),
                                                    batch_size=batch_size, class_mode='binary')
# Out:
# Found 43 images belonging to 2 classes.

# %%
# Data augmentation for validation images.
validation_datagen = ImageDataGenerator(preprocessing_function=preprocess_input, rotation_range=90,
                                        horizontal_flip=True, vertical_flip=True)
validation_generator = validation_datagen.flow_from_directory(validation_dir, target_size=(height, width),
                                                              batch_size=batch_size, class_mode='binary')
# Out:
# Found 29 images belonging to 2 classes.

# %%
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(height, width, 3))

# %%
# Add custom top layers for classification.
x = base_model.output
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(1, activation='sigmoid')(x)

# %%
# Combine base model with custom top layers
finetune_model = Model(inputs=base_model.input, outputs=predictions)

# %%
# Freeze layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# %%
# Compile the model
finetune_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
# Checkpoint and early stopping
checkpoint = ModelCheckpoint("best_model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stop = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True)

# %%
history = finetune_model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=100,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[]  # test with no callbacks
)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step - accuracy: 0.5745 - loss: 23.2405 - val_accuracy: 0.8621 - val_loss: 5.6202
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/100
# C:\Users\ASUS\anaconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.5797 - loss: 31.3930 - val_accuracy: 0.8276 - val_loss: 13.7288
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7689 - loss: 43.8168 - val_accuracy: 0.4828 - val_loss: 117.0864
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7586 - loss: 60.0814 - val_accuracy: 0.7586 - val_loss: 25.0903
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.6518 - loss: 67.4214 - val_accuracy: 0.8621 - val_loss: 19.2250
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.6942 - loss: 32.8557 - val_accuracy: 0.6897 - val_loss: 70.0953
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7617 - loss: 40.4563 - val_accuracy: 0.9310 - val_loss: 6.0505
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8287 - loss: 35.5671 - val_accuracy: 0.8276 - val_loss: 25.5776
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7741 - loss: 60.6393 - val_accuracy: 0.6207 - val_loss: 103.5464
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7276 - loss: 64.4452 - val_accuracy: 0.7586 - val_loss: 65.4307
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9632 - loss: 14.0872 - val_accuracy: 0.8276 - val_loss: 16.8001
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9323 - loss: 15.4136 - val_accuracy: 0.6552 - val_loss: 99.2463
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7759 - loss: 44.4407 - val_accuracy: 0.8966 - val_loss: 21.9948
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8011 - loss: 42.4553 - val_accuracy: 0.7586 - val_loss: 83.1936
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8292 - loss: 45.8316 - val_accuracy: 0.7241 - val_loss: 71.0517
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8972 - loss: 30.0392 - val_accuracy: 0.8621 - val_loss: 23.6898
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7103 - loss: 59.2188 - val_accuracy: 0.9655 - val_loss: 0.4299
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7251 - loss: 41.3175 - val_accuracy: 0.7931 - val_loss: 24.8120
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8359 - loss: 28.6380 - val_accuracy: 0.8621 - val_loss: 24.4022
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7712 - loss: 35.6550 - val_accuracy: 0.8276 - val_loss: 32.7241
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8022 - loss: 35.5427 - val_accuracy: 0.8621 - val_loss: 14.1808
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8243 - loss: 30.8230 - val_accuracy: 0.8966 - val_loss: 10.4362
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8012 - loss: 32.0093 - val_accuracy: 0.7241 - val_loss: 46.0142
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7843 - loss: 42.0462 - val_accuracy: 0.7241 - val_loss: 43.4356
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8274 - loss: 50.4048 - val_accuracy: 0.7586 - val_loss: 35.6554
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7757 - loss: 26.1017 - val_accuracy: 0.8966 - val_loss: 3.8131
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7521 - loss: 43.9617 - val_accuracy: 0.7931 - val_loss: 31.6139
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.8112 - loss: 22.6961 - val_accuracy: 0.6207 - val_loss: 48.8544
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 0.7450 - loss: 68.4611 - val_accuracy: 0.8621 - val_loss: 13.3285
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 0.8672 - loss: 20.8507 - val_accuracy: 0.8276 - val_loss: 15.8134
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.8405 - loss: 25.8719 - val_accuracy: 0.7241 - val_loss: 21.9760
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.8697 - loss: 32.1199 - val_accuracy: 0.8276 - val_loss: 22.4922
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.8946 - loss: 20.3016 - val_accuracy: 0.8966 - val_loss: 4.9225
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7881 - loss: 34.2947 - val_accuracy: 0.7241 - val_loss: 34.5078
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8217 - loss: 35.1711 - val_accuracy: 0.6897 - val_loss: 61.1976
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7801 - loss: 34.8631 - val_accuracy: 0.8621 - val_loss: 12.0794
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8743 - loss: 7.8672 - val_accuracy: 0.7931 - val_loss: 19.7029
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.8122 - loss: 33.2126 - val_accuracy: 0.9310 - val_loss: 2.9102
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.7567 - loss: 21.9142 - val_accuracy: 0.8621 - val_loss: 28.9571
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.7751 - loss: 47.2492 - val_accuracy: 0.7931 - val_loss: 33.0363
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8639 - loss: 16.7373 - val_accuracy: 0.7931 - val_loss: 23.0446
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8673 - loss: 20.4115 - val_accuracy: 0.8621 - val_loss: 12.3670
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8149 - loss: 15.8222 - val_accuracy: 0.8966 - val_loss: 6.9901
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.7832 - loss: 12.2525 - val_accuracy: 0.7931 - val_loss: 22.6959
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7381 - loss: 34.2510 - val_accuracy: 0.8966 - val_loss: 6.2021
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8370 - loss: 24.6358 - val_accuracy: 0.8966 - val_loss: 11.1492
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8318 - loss: 9.5712 - val_accuracy: 0.8966 - val_loss: 4.4785
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8396 - loss: 5.2767 - val_accuracy: 0.8966 - val_loss: 6.7670
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.8330 - loss: 14.2314 - val_accuracy: 0.8621 - val_loss: 13.5230
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9012 - loss: 9.7940 - val_accuracy: 0.8621 - val_loss: 6.9720
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00

# %%
# Plot training and validation accuracy over epochs.
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot training and validation loss over epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Testing the model
def predict_image(model, img_path):
    img = image.load_img(img_path, target_size=(height, width))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    prediction = model.predict(img_array)
    if prediction[0][0] > 0.5:
        return "Real"
    else:
        return "Fake"

# %%
# Specify the image path
test_img_path ="C:/Users/ASUS/Downloads/Identification_of_Fake_Currency_Found_in_India-main/Identification_of_Fake_Currency_Found_in_India-main/Dataset(100)/Testing/Fake/2.png"

# Load and display the image
img = image.load_img(test_img_path)
plt.imshow(img)

# Predict the image and display the prediction
prediction = predict_image(finetune_model, test_img_path)

img_width, img_height = img.size

# Use plt.text to add the prediction on the image
plt.text(img_width - 160, 10,f'Prediction: {prediction}', fontsize=12, color='white', weight='bold', bbox=dict(facecolor='red', alpha=0.5))

# Show the modified plot
plt.show()

# Print the prediction in the console if needed
print("Prediction:", prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Prediction: Fake

# %%
# Specify the image path
test_img_path ="C:/Users/ASUS/Downloads/Identification_of_Fake_Currency_Found_in_India-main/Identification_of_Fake_Currency_Found_in_India-main/Dataset(100)/Testing/Real/1.jpg"

# Load and display the image
img = image.load_img(test_img_path)
plt.imshow(img)

# Predict the image and display the prediction
prediction = predict_image(finetune_model, test_img_path)

img_width, img_height = img.size

# Use plt.text to add the prediction on the image
plt.text(img_width - 160, 10,f'Prediction: {prediction}', fontsize=12, color='white', weight='bold', bbox=dict(facecolor='red', alpha=0.5))

# Show the modified plot
plt.show()

# Print the prediction in the console if needed
print("Prediction:", prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# Prediction: Real

# %%
# Calculate overall accuracy of the model on the training set
overall_accuracy_training = finetune_model.evaluate(train_generator, steps=len(train_generator), verbose=1)

# Print overall accuracy on training set
print("Overall Accuracy on Training Set:", overall_accuracy_training[1])
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 532ms/step - accuracy: 0.8715 - loss: 16.6828
# Overall Accuracy on Training Set: 0.8837209343910217

# %%
# Calculate overall accuracy of the model on the validation set.
overall_accuracy =finetune_model.evaluate(validation_generator, steps=len(validation_generator), verbose=1)

# Print overall accuracy.
print("Validation Accuracy:", overall_accuracy[1])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 524ms/step - accuracy: 0.9295 - loss: 3.3199
# Validation Accuracy: 0.8965517282485962

# %%
# Predict the whole validation set
validation_generator_predict = validation_datagen.flow_from_directory(validation_dir, target_size=(height, width),
                                                                      batch_size=batch_size, class_mode='binary', shuffle=False)
validation_generator_predict.reset()
predictions = finetune_model.predict(validation_generator_predict, steps=len(validation_generator_predict), verbose=1)
predicted_classes = (predictions > 0.5).astype(int)
true_classes = validation_generator_predict.classes

# Confusion Matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', xticklabels=['Fake', 'Real'], yticklabels=['Fake', 'Real'])
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Found 29 images belonging to 2 classes.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step
